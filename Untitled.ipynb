# %%
import Pkg; 
Pkg.add("Plots");
using Plots
x = 1:10; y = rand(10); # These are the plotting data
plot(x, y)
# Out:
#    Resolving package versions...
#   No Changes to `C:\Users\santi\.julia\environments\v1.7\Project.toml`
#   No Changes to `C:\Users\santi\.julia\environments\v1.7\Manifest.toml`
